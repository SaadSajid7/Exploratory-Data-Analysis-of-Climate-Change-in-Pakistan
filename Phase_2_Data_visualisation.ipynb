# %% [markdown]
# <a href="https://colab.research.google.com/github/SaadSajid7/Exploratory-Data-Analysis-of-Climate-Change-in-Pakistan/blob/main/Phase_2_Data_visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xlrd
import seaborn as sns
sns.set(color_codes= True)
from scipy import stats
from operator import itemgetter
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7ab6effe-82a3-4769-b6ec-9b2a73cbf575" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ab6effe-82a3-4769-b6ec-9b2a73cbf575">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving climate-change-indicators-for-pakistan-1.csv to climate-change-indicators-for-pakistan-1.csv

# %%
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
# User uploaded file "climate-change-indicators-for-pakistan-1.csv" with length 227054 bytes

# %%
uploaded
# Out:
# {'climate-change-indicators-for-pakistan-1.csv': b'Country Name,Country ISO3,Year,Indicator Name,Indicator Code,Value\r\n#country+name,#country+code,#date+year,#indicator+name,#indicator+code,#indicator+value+num\r\nPakistan,PAK,2016,Agricultural land (sq. km),AG.LND.AGRI.K2,368440\r\nPakistan,PAK,2015,Agricultural land (sq. km),AG.LND.AGRI.K2,362020\r\nPakistan,PAK,2014,Agricultural land (sq. km),AG.LND.AGRI.K2,362520\r\nPakistan,PAK,2013,Agricultural land (sq. km),AG.LND.AGRI.K2,362800\r\nPakistan,PAK,2012,Agricultural land (sq. km),AG.LND.AGRI.K2,360630\r\nPakistan,PAK,2011,Agricultural land (sq. km),AG.LND.AGRI.K2,359360\r\nPakistan,PAK,2010,Agricultural land (sq. km),AG.LND.AGRI.K2,352420\r\nPakistan,PAK,2009,Agricultural land (sq. km),AG.LND.AGRI.K2,352770\r\nPakistan,PAK,2008,Agricultural land (sq. km),AG.LND.AGRI.K2,353130\r\nPakistan,PAK,2007,Agricultural land (sq. km),AG.LND.AGRI.K2,360130\r\nPakistan,PAK,2006,Agricultural land (sq. km),AG.LND.AGRI.K2,361350\r\nPakistan,PAK
# ...

# %%
df=pd.read_csv('climate-change-indicators-for-pakistan-1.csv')

# %%
df.head()
# Out:
#     Country Name   Country ISO3  ...   Indicator Code                 Value
# 0  #country+name  #country+code  ...  #indicator+code  #indicator+value+num
# 1       Pakistan            PAK  ...   AG.LND.AGRI.K2                368440
# 2       Pakistan            PAK  ...   AG.LND.AGRI.K2                362020
# 3       Pakistan            PAK  ...   AG.LND.AGRI.K2                362520
# 4       Pakistan            PAK  ...   AG.LND.AGRI.K2                362800
#
# [5 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2330 entries, 0 to 2329
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    2330 non-null   object
#  1   Country ISO3    2330 non-null   object
#  2   Year            2330 non-null   object
#  3   Indicator Name  2330 non-null   object
#  4   Indicator Code  2330 non-null   object
#  5   Value           2330 non-null   object
# dtypes: object(6)
# memory usage: 109.3+ KB

# %%
print(f"Shape: {df.shape}")
print(f"Size: {df.size}")
# Out:
# Shape: (2330, 6)
# Size: 13980

# %%
df.describe()
# Out:
#        Country Name Country ISO3  Year     Indicator Name Indicator Code Value
# count          2330         2330  2330               2330           2330  2330
# unique            2            2    61                 77             77  2163
# top        Pakistan          PAK  2010  Population, total    SP.POP.GROW     0
# freq           2329         2329    65                 59             59    94

# %%
df["Indicator Name"].loc[2160:2170]
# Out:
# 2160    Urban population growth (annual %)
# 2161    Urban population growth (annual %)
# 2162    Urban population growth (annual %)
# 2163    Urban population growth (annual %)
# 2164    Urban population growth (annual %)
# 2165    Urban population growth (annual %)
# 2166    Urban population growth (annual %)
# 2167    Urban population growth (annual %)
# 2168    Urban population growth (annual %)
# 2169    Urban population growth (annual %)
# 2170    Urban population growth (annual %)
# Name: Indicator Name, dtype: object

# %%
df["Year"].loc[2160:2170]
# Out:
# 2160    2011
# 2161    2010
# 2162    2009
# 2163    2008
# 2164    2007
# 2165    2006
# 2166    2005
# 2167    2004
# 2168    2003
# 2169    2002
# 2170    2001
# Name: Year, dtype: object

# %%
x = df['Year'].loc[2273:2283]
y = df['Value'].loc[2273:2283]

# Bar chart
plt.title('Population Growth Annually')
plt.xlabel('Year', fontsize=16)
plt.ylabel('Population(%)', fontsize=16)
plt.bar(x , y)

plt.show()

# %%
# Line Graph
plt.title('Population Growth Annually')
plt.xlabel('Year', fontsize=16)
plt.ylabel('Population(%)', fontsize=16)
plt.plot(x, y)

plt.show()
